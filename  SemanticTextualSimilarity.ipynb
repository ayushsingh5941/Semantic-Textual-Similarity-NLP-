# %%
import pandas as pd
import numpy as np
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import names, stopwords
from gensim import utils
from gensim.models.doc2vec import LabeledSentence
from gensim.models.doc2vec import TaggedDocument
from gensim.models import Doc2Vec
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Importing File

# %%
data = pd.read_csv('Text_Similarity_Dataset.csv')

# %% [markdown]
# # Data Familiarization

# %%
data.head(10)
# Out:
#    Unique_ID                                              text1  \
# 0          0  savvy searchers fail to spot ads internet sear...
# 1          1  millions to miss out on the net by 2025  40% o...
# 2          2  young debut cut short by ginepri fifteen-year-...
# 3          3  diageo to buy us wine firm diageo  the world s...
# 4          4  be careful how you code a new european directi...
# 5          5  india seeks to boost construction india has cl...
# 6          6  podcasters  look to net money nasa is doing it...
# 7          7  row over  police  power for csos the police fe...
# 8          8  election  could be terror target  terrorists m...
# 9          9  japan economy slides to recession the japanese...
#
#                                                text2
# 0  newcastle 2-1 bolton kieron dyer smashed home ...
# 1  nasdaq planning $100m share sale the owner of ...
# 2  ruddock backs yapp s credentials wales coach m...
# 3  mci shares climb on takeover bid shares in us ...
# 4  media gadgets get moving pocket-sized devices ...
# 5  music mogul fuller sells company pop idol supr...
# 6  ukip outspent labour on eu poll the uk indepen...
# 7  ban on hunting comes into force fox hunting wi...
# 8  nhs waiting time target is cut hospital waitin...
# 9  optimism remains over uk housing the uk proper...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4023 entries, 0 to 4022
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Unique_ID  4023 non-null   int64
#  1   text1      4023 non-null   object
#  2   text2      4023 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 94.4+ KB

# %%
data.isna().sum()
# Out:
# Unique_ID    0
# text1        0
# text2        0
# dtype: int64

# %%
print('Size of data', data.shape)
# Out:
# Size of data (4023, 3)

# %%
text_size1 = data['text1'].apply(lambda x: len(x.split(' '))).sum()
text_size2 = data['text2'].apply(lambda x: len(x.split(' '))).sum()
print('Total number of words in document', text_size1+text_size2)
# Out:
# Total number of words in document 3383889

# %% [markdown]
# There are total 4023 rows and 3 columns. columns are Unique_ID, text1 and text2. we will drop Unique_ID column as it is not relevant to us or we can simply make Unique_ID as index column for data.
# This data set do not have any missing values. Total 33,83,889 words

# %%
Unique_ID = data['Unique_ID']

# %%
data.drop('Unique_ID', axis=1, inplace=True)

# %% [markdown]
# # Data Clean Up

# %% [markdown]
# Initializing stopwords, all names, English()

# %%
stop_words = set(stopwords.words('english'))

# %%
all_names = set(names.words())

# %%
lemma = WordNetLemmatizer()

# %% [markdown]
# Functions to clean data

# %%
def cleaned_string(string):
    """
    Function to clean each string of dataset
    """
    # Removing all the digits
    string = re.sub(r'\d', '', string)
    
    # Removing Mentions
    string = re.sub(r'@\w+', ' ', string)
    
    # Removing links 
    string = re.sub(r'(https?:\/\/)?([\da-zA-Z\.-\/\#\:]+)\.([\da-zA-Z\.\/\:\#]{0,9})([\/\w \.-\/\:\#]*)', ' ', string)
    
    # Removing all the digits special caharacters
    string = re.sub(r'\W', ' ', string)
        
  
   
    string = string.strip()
    
    #Removing all Single characters
    string = re.sub(r"\b[a-zA-Z]\b", "", string)
    
    
    # Lemmetizing the string and removing stop words
    string = string.split()
    string = [lemma.lemmatize(word) for word in string if word not in stop_words]
    string = ' '.join(string)
    
    # Lowercasing all data
    string = string.lower()
        
    return string

# %%
def clean_text(data):
    """
    Function to retrieve each value in dataset and pass it through cleaned_string function.
    """
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            data.iloc[i, j] = cleaned_string(data.iloc[i, j])
    return data

# %%
x = clean_text(data)

# %%
x.head()
# Out:
#                                                text1  \
# 0  savvy searcher fail spot ad internet search en...
# 1  million miss net uk population still without i...
# 2  young debut cut short ginepri fifteen year old...
# 3  diageo buy u wine firm diageo world biggest sp...
# 4  careful code new european directive could put ...
#
#                                                text2
# 0  newcastle bolton kieron dyer smashed home winn...
# 1  nasdaq planning share sale owner technology do...
# 2  ruddock back yapp credential wale coach mike r...
# 3  mci share climb takeover bid share u phone com...
# 4  medium gadget get moving pocket sized device l...

# %%
text_size1 = x['text1'].apply(lambda x: len(x.split(' '))).sum()
text_size2 = x['text2'].apply(lambda x: len(x.split(' '))).sum()
print('Total number of words in document after preocessing', text_size1+text_size2)
# Out:
# Total number of words in document after preocessing 461962

# %% [markdown]
# This is a relatively small dataset with only 4,48,910 words

# %% [markdown]
# # Data preparation

# %% [markdown]
# Data splited in array to label it because doc2vec requires labeled data

# %%
def process_text(text_list, texts, text_list_name):
# function to transform questions and display progress
    for text in texts:
        text_list.append(text)

# %%
text1 = []
process_text(text1, x['text1'], 'text1')

# %%
text2 = []
process_text(text2, x['text2'], 'text2')

# %%
text_labeled = []

# %%
for i in range(len(text1)):
    # Text strings need to be separated into words
    # Each Text string needs a unique label
    text_labeled.append(TaggedDocument(text1[i].split( ), data[data.index ==i]))
    text_labeled.append(TaggedDocument(text2[i].split( ), data[data.index ==i]))

# %%
text_labeled
# Out:
# [TaggedDocument(words=['savvy', 'searcher', 'fail', 'spot', 'ad', 'internet', 'search', 'engine', 'user', 'odd', 'mix', 'naive', 'sophisticated', 'suggests', 'report', 'search', 'searcher', 'usually', 'find', 'looking', 'using', 'search', 'result', 'organic', 'net', 'user', 'say', 'regularly', 'use', 'google', 'ask', 'jeeves', 'msn', 'yahoo', 'questioned', 'said', 'would', 'trust', 'search', 'engine', 'much', 'le', 'knew', 'information', 'paid', 'result', 'carry', 'search', 'least', 'weekly', 'asked', 'look', 'every', 'questioned', 'information', 'looking', 'critical', 'information', 'simply', 'searcher', 'use', 'single', 'search', 'engine', 'use', 'two', 'three', 'small', 'number', 'consult', 'three', 'said', 'really', 'miss', 'search', 'engine', 'said', 'could', 'live', 'without', 'search', 'third', 'questioned', 'said', 'thought', 'result', 'presented', 'fair', 'unbiased', 'selection', 'information', 'topic', 'found', 'result', 'many', 'search', 'engine', 'provide', 'alongside', 'list', 'website', 'found', 'indexing', 'unaware', 'someone', 'paid', 'result', 'see', 'carry', 'searcher', 'say', 'tell', 'result', 'paid'], tags=                                               text1  \
#  0  savvy searcher fail spot ad internet search en...
#
#                                                 text2
#  0  newcastle bolton kieron dyer smashed home winn...  ),
#  TaggedDocument(words=['newcastle', 'bolton', 'kieron', 'dyer', 'smashed', 'home', 'winner', 'end', 'bolton', 'game', 'unbeaten', 'struck', 'half', 'keeping', 'shearer', 'low', 'shot', 'dyer', 'close', 'range', 'header', 'goalmouth', 'action', 'way', 'line', 'striding', 'forward', 'picked', 'carr', 'jay', 'okocha', 'twisted', 'turned', 'edge', 'area', 'neat', 'exchange', 'pass', 'involving', 'kevin', 'davy', 'gary', 'speed', 'greek', 'striker', 'found', 'bottom', 'corner', 'first', 'time', 'time', 'davy', 'set', 'giannakopoulos', 'space', 'given', 'block', 'near', 'taken', 'lead', 'first', 'meaningful', 'attack', 'second', 'kick', 'laurent', 'robert', 'curled', 'ball', 'shot', 'charged', 'dyer', 'reacted', 'first', 'smash', 'ball', 'past', 'despairing', 'jaaskelainen', 'six', 'bolton', 'bos', 'sam', 'allardyce', 'bitterly', 'disappointed', 'result', 'probably', 'disappointed', 'second', 'half', 'newcastle', 'bos', 'graeme', 'souness', 'deserved', 'jena', 'ameobi', 'fadiga', 'gotty', 'ben', 'haim', 'candela', 'giannakopoulos', 'okocha', 'vaz', 'te', 'hierro', 'campo', 'speed', 'gardner', 'gloucestershire'], tags=                                               text1  \
#  0  savvy searcher fail spot ad internet search en...
#
#                                                 text2
#  0  newcastle bolton kieron dyer smashed home winn...  ),
#  TaggedDocument(words=['million', 'miss', 'net', 'uk', 'population', 'still', 'without', 'internet', 'access', 'home', 'say', 'uk', 'currently', 'net', 'nots', 'much', 'talked', 'prediction', 'divide', 'affect', 'future', 'generation', 'le', 'friendly', 'technology', 'bridge', 'digital', 'divide', 'could', 'way', 'mark', 'report', 'nots', 'engaging', 'nots', 'disabled', 'make', 'elderly', 'nearly', 'third', 'report'], tags=                                               text1  \
#  1  million miss net uk population still without i...
#
#                                                 text2
#  1  nasdaq planning share sale owner technology do...  ),
#  TaggedDocument(words=['nasdaq', 'planning', 'share', 'sale', 'owner', 'technology', 'dominated', 'nasdaq', 'stock', 'index', 'plan', 'sell', 'share', 'public', 'list', 'market', 'diving', 'bubble'], tags=                                               text1  \
#  1  million miss net uk population still without i...
#
#                                                 text2
#  1  nasdaq planning share sale owner technology do...  ),
#  TaggedDocument(words=['young', 'debut', 'cut', 'short', 'ginepri', 'fifteen', 'year', 'old', 'donald', 'young', 'first', 'appearance', 'atp', 'tennis', 'tournament', 'proved', 'brief', 'teenager', 'went', 'round', 'one', 'san', 'jose', 'first', 'set', 'losing', 'next', 'six', 'year', 'older', 'youngest', 'player', 'ever', 'win', 'junior', 'slam', 'top', 'global', 'standing', 'admitted', 'handed', 'quick', 'around', 'taik', 'lee', 'defeated', 'american', 'jan', 'michael', 'gambill', 'american', 'kevin', 'kim', 'defeated', 'jan', 'hernych', 'czech', 'republic', 'canadian', 'qualifier', 'frank', 'dancevic', 'downed', 'american', 'jeff', 'morrison', 'denmark', 'kenneth', 'carlsen', 'beat', 'irakli', 'labadze', 'republic', 'georgia', 'top', 'seed', 'andy', 'roddick', 'launch', 'defence', 'title', 'wednesday', 'qualifier', 'paul'], tags=                                               text1  \
#  2  young debut cut short ginepri fifteen year old...
#
#                                                 text2
#  2  ruddock back yapp credential wale coach mike r...  ),
#  TaggedDocument(words=['ruddock', 'back', 'yapp', 'credential', 'wale', 'coach', 'mike', 'ruddock', 'say', 'john', 'yapp', 'take', 'year', 'old', 'blue', 'prop', 'uncapped', 'player', 'wale', 'six', 'nation', 'squad', 'gaining', 'chance', 'absence', 'osprey', 'loose', 'head', 'duncan', 'carrier', 'high', 'tackle', 'forward', 'impress', 'defence', 'work', 'rate', 'international', 'reckoning', 'since', 'falling', 'former', 'coach', 'steve', 'hansen', 'send', 'message', 'player', 'recognised', 'talent', 'pace', 'skill'], tags=                                               text1  \
#  2  young debut cut short ginepri fifteen year old...
#
#                                                 text2
#  2  ruddock back yapp credential wale coach mike r...  ),
#  TaggedDocument(words=['diageo', 'buy', 'u', 'wine', 'firm', 'diageo', 'world', 'biggest', 'spirit', 'company', 'agreed', 'buy', 'californian', 'wine', 'company', 'chalone', 'cash', 'known', 'brand', 'include', 'smirnoff', 'vodka', 'guinness', 'stout', 'already', 'u', 'winemaking', 'arm', 'diageo', 'chateau', 'estate', 'bn', 'bn', 'year'], tags=                                               text1  \
#  3  diageo buy u wine firm diageo world biggest sp...
#
#                                                 text2
#  3  mci share climb takeover bid share u phone com...  ),
#  TaggedDocument(words=['mci', 'share', 'climb', 'takeover', 'bid', 'share', 'u', 'phone', 'company', 'mci', 'risen', 'speculation', 'takeover', 'bn', 'bn', 'largest', 'u', 'long', 'distance', 'phone', 'firm', 'may', 'table', 'rival', 'bid', 'analyst', 'dollar', 'telecom', 'deal', 'since', 'line', 'phone', 'provider', 'mci', 'seen', 'overtaken', 'based', 'bn', 'company', 'collapsed', 'worker', 'lost', 'bn'], tags=                                               text1  \
#  3  diageo buy u wine firm diageo world biggest sp...
#
#                                                 text2
#  3  mci share climb takeover bid share u phone com...  ),
#  TaggedDocument(words=['careful', 'code', 'new', 'european', 'directive', 'could', 'put', 'software', 'writer', 'risk', 'legal', 'action', 'warns', 'former', 'programmer', 'technology', 'analyst', 'bill', 'implemented', 'invention', 'way', 'amends', 'article', 'european', 'patent', 'convention', 'yet', 'new', 'directive', 'nodded', 'next', 'meeting', 'one', 'eu', 'ministerial', 'council', 'seems', 'likely', 'allow', 'program', 'patented', 'europe', 'enter', 'unless', 'amazon', 'let', 'hold', 'patent', 'one', 'click', 'online', 'implemented', 'invention', 'going', 'since', 'least', 'mid', 'presented', 'original', 'based', 'already', 'cope', 'legal', 'environment', 'allows', 'license', 'patent', 'browser', 'infringed', 'eolas'], tags=                                               text1  \
#  4  careful code new european directive could put ...
#
#                                                 text2
#  4  medium gadget get moving pocket sized device l...  ),
#  TaggedDocument(words=['medium', 'gadget', 'get', 'moving', 'pocket', 'sized', 'device', 'let', 'people', 'carry', 'around', 'video', 'image', 'set', 'big', 'year', 'according', 'industry', 'based', 'creative', 'zen', 'portable', 'medium', 'player', 'samsung', 'yepp', 'iriver', 'pmc', 'archos', 'av', 'series', 'among', 'based', 'portable', 'medium', 'device', 'consumer', 'electronics', 'show', 'la', 'vega', 'fi', 'capability', 'built', 'first', 'based', 'player', 'archos', 'av', 'series', 'device', 'always', 'able', 'record', 'video', 'source', 'tv', 'well', 'fi', 'connectivity', 'open', 'possibility', 'content', 'delivery', 'via', 'high', 'speed', 'wireless', 'based', 'portable', 'medium', 'player', 'based', 'device', 'offer', 'certainly', 'give', 'people', 'content', 'watch', 'go', 'european', 'wanted', 'watch', 'video', 'cool', 'consumer', 'going', 'european', 'content', 'supplier', 'offer', 'similar', 'fi', 'professional', 'maker', 'video', 'audio', 'take', 'advantage', 'growing', 'portable', 'medium', 'market', 'distribute'], tags=                                               text1  \
#  4  careful code new european directive could put ...
#
#                                                 text2
#  4  medium gadget get moving pocket sized device l...  ),
#  TaggedDocument(words=['india', 'seek', 'boost', 'construction', 'india', 'cleared', 'proposal', 'allowing', 'foreign', 'direct', 'investment', 'construction', 'allowed', 'automatic', 'route', 'construction', 'sector', 'project', 'including', 'housing', 'hotel', 'resort', 'hospital', 'educational', 'making', 'square', 'foot', 'within', 'specific', 'timeframe', 'said', 'mr', 'nath', 'without', 'specifying', 'international', 'real', 'estate', 'company', 'told', 'bbc', 'big', 'positive', 'citu', 'said', 'allowing', 'fdi', 'country', 'compromising', 'india', 'self', 'reliance', 'said', 'country', 'develop', 'basis', 'foreign', 'investment', 'term', 'employment', 'money', 'generated', 'another', 'way', 'international', 'company', 'filling', 'deep'], tags=                                               text1  \
#  5  india seek boost construction india cleared pr...
#
#                                                 text2
#  5  music mogul fuller sell company pop idol supre...  ),
#  TaggedDocument(words=['music', 'mogul', 'fuller', 'sell', 'company', 'pop', 'idol', 'supremo', 'simon', 'fuller', 'sold', 'entertainment', 'company', 'u', 'entrepreneur', 'share', 'estate', 'elvis', 'cash', 'million', 'share', 'sport', 'either', 'cash', 'stock', 'end', 'financial', 'year', 'term', 'agreement', 'company', 'see', 'continue', 'expand', 'develop', 'entertainment', 'paul'], tags=                                               text1  \
#  5  india seek boost construction india cleared pr...
#
#                                                 text2
#  5  music mogul fuller sell company pop idol supre...  ),
#  TaggedDocument(words=['podcasters', 'look', 'net', 'money', 'nasa', 'year', 'old', 'boy', 'bedroom', 'couple', 'gadget', 'lover', 'male', 'female', 'definitely', 'diy', 'radio', 'form', 'downloadable', 'mp', 'audio', 'based', 'weblogs', 'diary', 'like', 'site', 'people', 'share', 'playing', 'device', 'play', 'wmp', 'free', 'show', 'feed', 'new', 'podcast', 'available', 'automatically', 'sent', 'device', 'connected', 'like', 'daughter', 'listen', 'listening', 'classic', 'shifting', 'content', 'latest', 'industry', 'buzzword', 'able', 'listen', 'want', 'wherever', 'committed', 'daily', 'inspire', 'community', 'thousand', 'really', 'simple', 'syndication', 'give', 'web', 'user', 'easy', 'way', 'keep', 'updated', 'automatically', 'site', 'running', 'weblog', 'net', 'scripting', 'hyped', 'business', 'mail', 'made', 'wow', 'pretty', 'interesting', 'face', 'type', 'familiar', 'commercial', 'radio', 'loving', 'curry', 'sold', 'worth', 'coffee', 'machine', 'referral', 'link', 'amazon', 'show', 'promotion', 'like', 'dawn', 'drew', 'disappear'], tags=                                               text1  \
#  6  podcasters look net money nasa year old boy be...
#
#                                                 text2
#  6  ukip outspent labour eu poll uk independence p...  ),
#  TaggedDocument(words=['ukip', 'outspent', 'labour', 'eu', 'poll', 'uk', 'independence', 'party', 'outspent', 'labour', 'liberal', 'democrat', 'european', 'election', 'new', 'figure', 'campaign', 'second', 'conservative', 'lib', 'dems', 'green', 'according', 'figure', 'revealed', 'electoral', 'commission', 'last', 'general'], tags=                                               text1  \
#  6  podcasters look net money nasa year old boy be...
#
#                                                 text2
#  6  ukip outspent labour eu poll uk independence p...  ),
#  TaggedDocument(words=['row', 'police', 'power', 'csos', 'police', 'federation', 'said', 'strongly', 'opposes', 'giving', 'community', 'support', 'officer', 'csos', 'power', 'detain', 'suspect', 'piloted', 'six', 'area', 'extended', 'police', 'force', 'england', 'wale', 'detaining', 'someone', 'clearly', 'visible', 'presence', 'combating', 'low', 'level', 'crime', 'anti', 'social'], tags=                                               text1  \
#  7  row police power csos police federation said s...
#
#                                                 text2
#  7  ban hunting come force fox hunting dog illegal...  ),
#  TaggedDocument(words=['ban', 'hunting', 'come', 'force', 'fox', 'hunting', 'dog', 'illegal', 'england', 'wale', 'ban', 'activity', 'came', 'force', 'drag', 'hunting', 'chasing', 'fox', 'shooting', 'hunting', 'lobby', 'expects', 'authority', 'prosecute', 'wherever', 'clear', 'evidence', 'illegal', 'hunting'], tags=                                               text1  \
#  7  row police power csos police federation said s...
#
#                                                 text2
#  7  ban hunting come force fox hunting dog illegal...  ),
#  TaggedDocument(words=['election', 'could', 'terror', 'target', 'terrorist', 'might', 'try', 'target', 'uk', 'run', 'election', 'london', 'senior', 'police', 'officer', 'poll', 'terror', 'proposal', 'warning', 'would', 'wrong', 'wait', 'attack', 'election', 'terror', 'plan', 'one', 'politician', 'police', 'would', 'enforce', 'new', 'style', 'pre', 'election', 'bombing', 'could', 'happen', 'uk'], tags=                                               text1  \
#  8  election could terror target terrorist might t...
#
#                                                 text2
#  8  nh waiting time target cut hospital waiting ti...  ),
#  TaggedDocument(words=['nh', 'waiting', 'time', 'target', 'cut', 'hospital', 'waiting', 'time', 'patient', 'wale', 'cut', 'extent', 'seeing', 'consultant', 'operation', 'six', 'bma', 'welcomed', 'new', 'target', 'make', 'faster', 'progress', 'waiting', 'list', 'however', 'much', 'remains', 'done', 'waiting', 'list', 'waiting', 'time', 'wale', 'still', 'lag', 'long', 'way', 'behind', 'england', 'health', 'service', 'spent', 'reducing', 'waiting', 'time', 'improving', 'key', 'area', 'modernising', 'staff', 'pay', 'structure', 'one', 'wait', 'year', 'treatment', 'see', 'statistic', 'end', 'november', 'showed', 'decline', 'since', 'october', 'number', 'waiting', 'month', 'also', 'fell', 'm', 'hutt', 'said', 'excellent', 'figure', 'people', 'waiting', 'list', 'kind', 'last'], tags=                                               text1  \
#  8  election could terror target terrorist might t...
#
#                                                 text2
#  8  nh waiting time target cut hospital waiting ti...  ),
#  TaggedDocument(words=['japan', 'economy', 'slide', 'recession', 'japanese', 'economy', 'officially', 'gone', 'back', 'recession', 'fourth', 'time', 'last', 'three', 'month', 'fall', 'reflects', 'weak', 'export', 'slowdown', 'consumer', 'spending', 'follows', 'similar', 'fall', 'gdp', 'two', 'previous', 'growth', 'july', 'september', 'downgraded', 'last', 'three', 'month', 'however', 'politician', 'remain', 'upbeat', 'prospect', 'economic', 'boost', 'later', 'factor', 'unseasonably', 'mild', 'overall', 'last', 'year', 'fuelled', 'strong', 'performance', 'first', 'month', 'forecast', 'see', 'growth', 'however', 'economy', 'fragile', 'recovery', 'remains', 'dependent', 'upturn', 'consumer', 'spending', 'fall', 'value', 'yen', 'improvement', 'global', 'ichi', 'life', 'research'], tags=                                               text1  \
#  9  japan economy slide recession japanese economy...
#
#                                                 text2
#  9  optimism remains uk housing uk property market...  ),
#  TaggedDocument(words=['optimism', 'remains', 'uk', 'housing', 'uk', 'property', 'market', 'remains', 'robust', 'despite', 'recent', 'slowdown', 'according', 'mortgage', 'lender', 'bradford', 'bingley', 'housebuilder', 'george', 'said', 'buy', 'let', 'market', 'bank', 'major', 'player', 'would', 'continue', 'grow', 'much', 'faster', 'wider', 'mortgage', 'rise', 'profit', 'wimpey', 'reported', 'rise', 'profit', 'said', 'recent', 'new', 'home', 'reservation', 'better', 'cml', 'indicated', 'popularity', 'buy', 'let', 'mortgage', 'key', 'phenomenon', 'housing', 'boom', 'could', 'share', 'uk', 'buy', 'let', 'mortgage', 'market', 'said', 'rate', 'growth', 'moderating', 'sector', 'continues', 'grow', 'rate', 'considerably', 'whole', 'mortgage', 'market', 'overall', 'said', 'housing', 'market', 'fundamental', 'remain', 'strong', 'interest', 'rate', 'unemployment', 'likely', 'remain', 'historically', 'low', 'level', 'real', 'household', 'income', 'continue', 'grow', 'housing', 'demand', 'likely', 'outstrip', 'supply', 'medium', 'morning', 'trade', 'analyst', 'worried', 'future', 'earnings', 'morning'], tags=                                               text1  \
#  9  japan economy slide recession japanese economy...
#
#                                                 text2
#  9  optimism remains uk housing uk property market...  ),
#  TaggedDocument(words=['lufthansa', 'fly', 'back', 'profit', 'german', 'airline', 'lufthansa', 'returned', 'profit', 'posting', 'huge', 'loss', 'preliminary', 'report', 'airline', 'announced', 'net', 'profit', 'euro', 'compared', 'loss', 'euro', 'operating', 'profit', 'euro', 'ten', 'time', 'lufthansa', 'hit', 'tough', 'competition', 'dip', 'demand', 'following', 'iraq', 'war', 'killer', 'sars'], tags=                                                text1  \
#  10  lufthansa fly back profit german airline lufth...
#
#                                                  text2
#  10  applegate charity show close u musical sweet c...  ),
#  TaggedDocument(words=['applegate', 'charity', 'show', 'close', 'u', 'musical', 'sweet', 'charity', 'cancelled', 'run', 'broadway', 'poor', 'ticket', 'sale', 'early', 'broadway', 'performance', 'earlier', 'month', 'broken', 'year', 'old', 'injured', 'performing', 'chicago', 'hoping', 'recover', 'time', 'official', 'new', 'york', 'opening', 'show', 'due', 'begin'], tags=                                                text1  \
#  10  lufthansa fly back profit german airline lufth...
#
#                                                  text2
#  10  applegate charity show close u musical sweet c...  ),
#  TaggedDocument(words=['sprinter', 'walker', 'quits', 'athletics', 'former', 'european', 'champion', 'dougie', 'walker', 'retire', 'athletics', 'series', 'six', 'operation', 'left', 'struggling', 'year', 'old', 'scot', 'suspended', 'two', 'year', 'testing', 'positive', 'decent', 'mark', 'might', 'motivated'], tags=                                                text1  \
#  11  sprinter walker quits athletics former europea...
#
#                                                  text2
#  11  ferguson urge henry punishment sir alex fergus...  ),
#  TaggedDocument(words=['ferguson', 'urge', 'henry', 'punishment', 'sir', 'alex', 'ferguson', 'called', 'football', 'association', 'punish', 'arsenal', 'thierry', 'henry', 'incident', 'involving', 'gabriel', 'game', 'time', 'freddie', 'ljungberg', 'challenge', 'left', 'heinze', 'ground', 'left', 'referee', 'mike', 'riley', 'deemed', 'collision', 'rival', 'praised', 'side', 'breaker', 'sixth', 'foul', 'got'], tags=                                                text1  \
#  11  sprinter walker quits athletics former europea...
#
#                                                  text2
#  11  ferguson urge henry punishment sir alex fergus...  ),
#  TaggedDocument(words=['gervais', 'writing', 'simpson', 'episode', 'office', 'ricky', 'gervais', 'writing', 'episode', 'hit', 'u', 'cartoon', 'simpson', 'following', 'invitation', 'creator', 'matt', 'one', 'best', 'show', 'tv', 'last', 'much', 'criticism', 'failed', 'live'], tags=                                                text1  \
#  12  gervais writing simpson episode office ricky g...
#
#                                                  text2
#  12  charge tv cosby u comedian bill cosby face cha...  ),
#  TaggedDocument(words=['charge', 'tv', 'cosby', 'u', 'comedian', 'bill', 'cosby', 'face', 'charge', 'stemming', 'allegation', 'sexual', 'hosting', 'child', 'show', 'fat', 'albert', 'cosby', 'kid', 'starring', 'cosby', 'show', 'one', 'biggest', 'sitcom'], tags=                                                text1  \
#  12  gervais writing simpson episode office ricky g...
#
#                                                  text2
#  12  charge tv cosby u comedian bill cosby face cha...  ),
#  TaggedDocument(words=['kenyan', 'school', 'turn', 'handhelds', 'mbita', 'point', 'primary', 'school', 'western', 'kenya', 'student', 'click', 'away', 'handheld', 'computer', 'date', 'information', 'student', 'currently', 'stuck', 'ancient', 'governmental', 'organisation', 'us', 'combination', 'satellite', 'radio', 'handheld', 'computer', 'called', 'slate', 'connect', 'via', 'wireless', 'connection', 'base', 'station', 'way', 'connection', 'getting', 'feedback', 'specific', 'request', 'end', 'user', 'based', 'slate', 'charge', 'day', 'child', 'school', 'take', 'home', 'night', 'continue', 'slate', 'say', 'project', 'ultimate', 'goal', 'levelling', 'access', 'knowledge', 'around', 'need'], tags=                                                text1  \
#  13  kenyan school turn handhelds mbita point prima...
#
#                                                  text2
#  13  woman turn net security older people woman inc...  ),
#  TaggedDocument(words=['woman', 'turn', 'net', 'security', 'older', 'people', 'woman', 'increasingly', 'taking', 'charge', 'protecting', 'home', 'computer', 'malicious', 'net', 'attack', 'according', 'two', 'year', 'year', 'study', 'net', 'security', 'firm', 'preventon', 'show', 'security', 'message', 'reaching', 'diversity', 'buying', 'home', 'net', 'security', 'program', 'retired', 'woman', 'buying', 'security', 'software', 'retired', 'speed', 'broadband', 'net', 'connection', 'pose', 'home', 'pc', 'net', 'security', 'buyer', 'woman', 'could', 'even', 'overtake', 'men', 'main', 'buyer', 'current', 'rate', 'persist', 'according', 'woman', 'took', 'part', 'sex', 'often', 'woman', 'access', 'user', 'slower', 'connection', 'said', 'mr', 'technical', 'language', 'mail', 'profile', 'complaint', 'rogue', 'diallers', 'spyware', 'program', 'surreptitiously', 'install', 'computer', 'also', 'raised', 'awareness', 'need', 'combination', 'anti', 'virus', 'firewall', 'spyware', 'removal', 'program', 'uk', 'home', 'broadband', 'net', 'first', 'time', 'according', 'office', 'national'], tags=                                                text1  \
#  13  kenyan school turn handhelds mbita point prima...
#
#                                                  text2
#  13  woman turn net security older people woman inc...  ),
#  TaggedDocument(words=['u', 'woman', 'sue', 'ink', 'cartridge', 'u', 'woman', 'suing', 'hewlett', 'packard', 'hp', 'saying', 'printer', 'ink', 'cartridge', 'secretly', 'programmed', 'expire', 'certain', 'filling', 'even', 'expiration', 'date', 'revealed', 'consumer', 'suit', 'could', 'cost', 'running', 'cost', 'month', 'period', 'due', 'cartridge', 'study', 'computeractive', 'magazine', 'revealed', 'last', 'oft', 'concluded', 'report', 'retailer', 'manufacturer', 'needed', 'make', 'pricing', 'transparent'], tags=                                                text1  \
#  14  u woman sue ink cartridge u woman suing hewlet...
#
#                                                  text2
#  14  power people say hp digital revolution focused...  ),
#  TaggedDocument(words=['power', 'people', 'say', 'hp', 'digital', 'revolution', 'focused', 'letting', 'people', 'tell', 'share', 'story', 'according', 'carly', 'fiorina', 'chief', 'technology', 'giant', 'hewlett', 'ce', 'ensure', 'digital', 'physical', 'world', 'fully', 'fest', 'largest', 'kind', 'world', 'run', 'stage', 'promote', 'range', 'hp', 'digital', 'camera', 'm', 'stefani', 'helped', 'design', 'heavily', 'influenced', 'japanese', 'youth', 'definition', 'tv', 'cable', 'set', 'top', 'box', 'digital', 'video', 'recorder', 'dvd', 'recorded', 'tv', 'show', 'picture', 'video', 'music', 'managed', 'one', 'box', 'pc', 'work', 'part', 'key', 'centre'], tags=                                                text1  \
#  14  u woman sue ink cartridge u woman suing hewlet...
#
#                                                  text2
#  14  power people say hp digital revolution focused...  ),
#  TaggedDocument(words=['bond', 'game', 'fails', 'shake', 'stir', 'gaming', 'fan', 'word', 'goldeneye', 'evokes', 'excited', 'memory', 'james', 'bond', 'revival', 'flick', 'also', 'classic', 'shoot', 'em', 'accompanied', 'left', 'owner', 'glued', 'console', 'many', 'chief', 'portly', 'auric', 'goldfinger', 'last', 'seen', 'happily', 'running', 'around', 'bent', 'world', 'titled', 'theme', 'song', 'game', 'literally', 'give', 'player', 'golden', 'eye', 'following', 'injury', 'enables', 'degree', 'ray', 'detection', 'suspect', 'difficulty', 'aiming', 'weapon', 'compensated', 'time', 'risked', 'measured', 'build', 'fiend', 'oddjob', 'crazed', 'russian', 'sex', 'beast', 'xenia', 'onatopp', 'resurrected', 'year', 'face', 'rendered', 'impressively', 'recognisable', 'game', 'niggles', 'combined', 'story', 'presentation', 'feel', 'sufficiently', 'well', 'thought', 'make', 'disappointment'], tags=                                                text1  \
#  15  bond game fails shake stir gaming fan word gol...
#
#                                                  text2
#  15  mobile multimedia slow catch doubt mobile phon...  ),
#  TaggedDocument(words=['mobile', 'multimedia', 'slow', 'catch', 'doubt', 'mobile', 'phone', 'sporting', 'camera', 'colour', 'screen', 'hugely', 'increase', 'number', 'phone', 'sold', 'third', 'quarter', 'according', 'analyst', 'gartner', 'million', 'handset', 'sold', 'july', 'september', 'period', 'according', 'gartner', 'analyst', 'carolina', 'milanesi', 'seldom', 'strong', 'although', 'consumer', 'mobile', 'take', 'send', 'snap', 'sound', 'video', 'clip', 'far', 'taking', 'chance', 'british', 'camera', 'phone', 'user', 'never', 'sent', 'multimedia', 'message', 'mm', 'despite', 'fact', 'period', 'number', 'camera', 'phone', 'uk', 'doubled', 'people', 'questioned', 'said', 'technophobe', 'tended', 'shy', 'away', 'regarded', 'technically', 'savvy', 'enough', 'send', 'picture', 'video', 'one', 'want', 'take', 'risk', 'swamping', 'relatively', 'narrow', 'channel', 'number', 'mm', 'message', 'capped', 'said', 'mr', 'push', 'get', 'multimedia', 'subscriber', 'hutch', 'alive', 'us', 'celltick', 'broadcast', 'technology', 'regularly', 'click', 'picture', 'sound', 'image'], tags=                                                text1  \
#  15  bond game fails shake stir gaming fan word gol...
#
#                                                  text2
#  15  mobile multimedia slow catch doubt mobile phon...  ),
#  TaggedDocument(words=['oscar', 'race', 'enters', 'final', 'furlong', 'race', 'oscar', 'entered', 'final', 'stage', 'deadline', 'voter', 'choose', 'winner', 'late', 'submission', 'included', 'year', 'old', 'actor', 'nominated', 'playing', 'howard', 'hughes', 'aviator', 'join', 'hopeful', 'co', 'star', 'cate', 'blanchett', 'natalie', 'portman', 'kate', 'winslet', 'oscar', 'known', 'name', 'film', 'organiser', 'say', 'expect', 'watched', 'television', 'one', 'billion', 'people', 'around', 'late', 'said', 'oscar', 'communication', 'director', 'john'], tags=                                                text1  \
#  16  oscar race enters final furlong race oscar ent...
#
#                                                  text2
#  16  label withdraws mcfadden video new video forme...  ),
#  TaggedDocument(words=['label', 'withdraws', 'mcfadden', 'video', 'new', 'video', 'former', 'westlife', 'singer', 'brian', 'mcfadden', 'pulled', 'dublin', 'school', 'complained', 'associated', 'song', 'irish', 'year', 'old', 'pop', 'star', 'attended', 'school', 'abused', 'topping', 'group', 'westlife', 'march', 'went', 'number', 'one', 'september', 'first', 'solo', 'single', 'real', 'topper', 'boy', 'band', 'parting', 'company'], tags=                                                text1  \
#  16  oscar race enters final furlong race oscar ent...
#
#                                                  text2
#  16  label withdraws mcfadden video new video forme...  ),
#  TaggedDocument(words=['charvis', 'set', 'lose', 'fitness', 'bid', 'flanker', 'colin', 'charvis', 'unlikely', 'play', 'part', 'wale', 'final', 'two', 'game', 'six'], tags=                                                text1  \
#  17  charvis set lose fitness bid flanker colin cha...
#
#                                                  text2
#  17  force strong battlefront warm reception greete...  ),
#  TaggedDocument(words=['force', 'strong', 'battlefront', 'warm', 'reception', 'greeted', 'star', 'war', 'battlefront', 'reflection', 'ingenious', 'innovation', 'gameplay', 'back', 'basic', 'approach', 'immense', 'nostalgia', 'gunfight', 'set', 'array', 'location', 'featured', 'hinted', 'two', 'blockbusting', 'film', 'person', 'perspective', 'either', 'fight', 'force', 'freedom', 'join', 'darth', 'vader', 'dark', 'side', 'depending', 'episode', 'type', 'campaign', 'well', 'player', 'personal', 'propensity', 'good', 'luke', 'at', 'maligned', 'ewoks', 'scale', 'standard', 'stuff', 'short', 'spawning', 'mile', 'away', 'action', 'irritating', 'price', 'pay', 'getting', 'blown', 'second', 'friendly', 'average', 'ai', 'enemy', 'see', 'although', 'given', 'frenetic', 'environment', 'operate', 'strategic', 'behaviour', 'need', 'trick', 'pony'], tags=                                                text1  \
#  17  charvis set lose fitness bid flanker colin cha...
#
#                                                  text2
#  17  force strong battlefront warm reception greete...  ),
#  TaggedDocument(words=['mobile', 'multimedia', 'slow', 'catch', 'doubt', 'mobile', 'phone', 'sporting', 'camera', 'colour', 'screen', 'hugely', 'increase', 'number', 'phone', 'sold', 'third', 'quarter', 'according', 'analyst', 'gartner', 'million', 'handset', 'sold', 'globally', 'july', 'september', 'period', 'according', 'gartner', 'analyst', 'carolina', 'milanesi', 'seldom', 'strong', 'although', 'consumer', 'mobile', 'take', 'send', 'snap', 'sound', 'video', 'clip', 'far', 'taking', 'chance', 'british', 'camera', 'phone', 'user', 'never', 'sent', 'multimedia', 'message', 'mm', 'despite', 'fact', 'period', 'number', 'camera', 'phone', 'uk', 'doubled', 'people', 'questioned', 'said', 'technophobe', 'tended', 'shy', 'away', 'regarded', 'technically', 'savvy', 'enough', 'send', 'picture', 'video', 'one', 'want', 'take', 'risk', 'swamping', 'relatively', 'narrow', 'channel', 'number', 'mm', 'message', 'capped', 'said', 'mr', 'push', 'get', 'multimedia', 'subscriber', 'hutch', 'alive', 'us', 'celltick', 'broadcast', 'technology', 'regularly', 'click', 'picture', 'sound', 'image'], tags=                                                text1  \
#  18  mobile multimedia slow catch doubt mobile phon...
#
#                                                  text2
#  18  text message aid disaster recovery text messag...  ),
#  TaggedDocument(words=['text', 'message', 'aid', 'disaster', 'recovery', 'text', 'messaging', 'technology', 'valuable', 'communication', 'tool', 'aftermath', 'tsunami', 'disaster', 'ground', 'assessment', 'need', 'blogging', 'friend', 'india', 'took', 'mr', 'senanayake', 'text', 'message', 'posted', 'weblog', 'called', 'dog', 'without', 'mail', 'message', 'human', 'machine', 'moderator', 'mail', 'aid', 'agency', 'get', 'mail', 'message', 'asking', 'help', 'creating', 'system', 'source', 'software', 'software', 'used', 'anyone', 'without', 'commercial', 'restraint', 'far', 'flung', 'network', 'talent', 'create', 'system', 'link', 'need', 'organizing', 'larger', 'enterprise', 'thing', 'benefit', 'people', 'say', 'paul', 'saffo', 'director', 'california', 'based', 'institute', 'mail', 'away', 'said', 'put', 'whole', 'new', 'dimension', 'disaster', 'relief', 'recovery', 'often', 'people', 'halfway', 'around', 'world', 'effective', 'making', 'something', 'happen', 'precisely', 'right', 'top', 'mail', 'dan', 'lane', 'call', 'early', 'proof', 'page', 'distribute', 'mail', 'human', 'boston', 'co'], tags=                                                text1  \
#  18  mobile multimedia slow catch doubt mobile phon...
#
#                                                  text2
#  18  text message aid disaster recovery text messag...  ),
#  TaggedDocument(words=['u', 'firm', 'bid', 'lacroix', 'label', 'u', 'firm', 'said', 'final', 'negotiation', 'luxury', 'good', 'group', 'lvmh', 'buy', 'loss', 'making', 'christian', 'lacroix', 'haute', 'couture', 'based', 'lvmh', 'selling', 'non', 'core', 'business', 'focusing', 'profitable', 'label', 'including', 'moet', 'chandon', 'champagne', 'louis', 'held', 'falic', 'group', 'bought', 'two', 'cosmetic', 'brand', 'hard', 'candy', 'urban', 'decay', 'lvmh', 'early', 'florida', 'company', 'also', 'chain', 'duty', 'free', 'store'], tags=                                                text1  \
#  19  u firm bid lacroix label u firm said final neg...
#
#                                                  text2
#  19  yukos seek court action sale yukos return u co...  ),
#  TaggedDocument(words=['yukos', 'seek', 'court', 'action', 'sale', 'yukos', 'return', 'u', 'court', 'wednesday', 'seek', 'sanction', 'baikal', 'finance', 'group', 'little', 'known', 'firm', 'bought', 'main', 'bn', 'bought', 'yuganskneftegas', 'production', 'unit', 'bn', 'bn', 'rouble', 'bn', 'sunday', 'state', 'provoked', 'auction', 'strong', 'link', 'surgutneftegas', 'russia', 'fourth', 'biggest', 'oil', 'yukos', 'oil', 'output', 'could', 'ultimately', 'fall', 'hand', 'surgutneftegas', 'even', 'gazprom', 'state', 'gas', 'firm', 'opted', 'bn', 'back', 'tax', 'bill', 'say', 'company'], tags=                                                text1  \
#  19  u firm bid lacroix label u firm said final neg...
#
#                                                  text2
#  19  yukos seek court action sale yukos return u co...  ),
#  TaggedDocument(words=['owen', 'determined', 'stay', 'madrid', 'england', 'forward', 'michael', 'owen', 'told', 'bbc', 'happy', 'spain', 'plan', 'quit', 'real', 'madrid', 'return', 'premiership', 'near', 'year', 'old', 'spent', 'much', 'time', 'coming', 'bench', 'la', 'liga', 'rule', 'return', 'premiership', 'choice', 'striker', 'going', 'sat', 'bench', 'time', 'much', 'press', 'like', 'build', 'permanently', 'backside', 'bench', 'played', 'many', 'game', 'anyone', 'else', 'team', 'choice', 'striker', 'start', 'happy', 'way', 'settled', 'glad', 'one', 'forgetting', 'wished', 'better', 'start', 'listen', 'full', 'interview', 'garry', 'richardson', 'bbc', 'radio', 'five', 'live', 'sportsweek', 'gmt'], tags=                                                text1  \
#  20  owen determined stay madrid england forward mi...
#
#                                                  text2
#  20  foster buy stake winemaker australian brewer f...  ),
#  TaggedDocument(words=['foster', 'buy', 'stake', 'winemaker', 'australian', 'brewer', 'foster', 'bought', 'large', 'stake', 'australian', 'winemaker', 'southcorp', 'sparking', 'rumour', 'possible', 'southcorp', 'global', 'winemaker', 'behind', 'penfolds', 'lindemans', 'rosemount', 'brand', 'australian', 'dollar', 'per', 'bn', 'bn', 'bn', 'foster', 'said', 'currently', 'discussion', 'may', 'lead', 'major', 'corporate', 'announcement', 'separate', 'statement', 'southcorp', 'confirmed', 'brewer', 'asked', 'stake', 'reline', 'investment', 'family', 'investment', 'firm', 'oatleys', 'founded', 'rosemount', 'estate', 'label', 'sold', 'southcorp', 'robert', 'oatley', 'son', 'sandy', 'oatley', 'resigned', 'southcorp', 'board', 'following', 'share', 'selling', 'property', 'business', 'lensworth', 'widely', 'expected', 'return', 'cash', 'flip', 'said', 'shawn', 'burn', 'fund', 'manger', 'deutsche', 'asset', 'bn', 'since', 'paid', 'bn', 'u', 'wine', 'maker', 'robert', 'mondavi', 'bought', 'last'], tags=                                                text1  \
#  20  owen determined stay madrid england forward mi...
#
#                                                  text2
#  20  foster buy stake winemaker australian brewer f...  ),
#  TaggedDocument(words=['bookmaker', 'back', 'aviator', 'oscar', 'aviator', 'tipped', 'uk', 'bookmaker', 'favourite', 'win', 'best', 'film', 'award', 'year'], tags=                                                text1  \
#  21  bookmaker back aviator oscar aviator tipped uk...
#
#                                                  text2
#  21  alicia key open u super bowl star alicia key o...  ),
#  TaggedDocument(words=['alicia', 'key', 'open', 'u', 'super', 'bowl', 'star', 'alicia', 'key', 'open', 'february', 'super', 'bowl', 'singing', 'song', 'previously', 'performed', 'ray', 'charles', 'vicki', 'time', 'entertainment', 'slot', 'filled', 'janet', 'jackson', 'last', 'baring', 'incident', 'sparked', 'thousand', 'complaint', 'u', 'tv', 'watched', 'owned', 'tv', 'station', 'fined', 'country', 'tv', 'regulatory', 'agency', 'complaint', 'made', 'janet', 'jackson', 'wardrobe', 'malfunction', 'sir', 'paul', 'said', 'nothing', 'bigger', 'asked', 'perform', 'super'], tags=                                                text1  \
#  21  bookmaker back aviator oscar aviator tipped uk...
#
#                                                  text2
#  21  alicia key open u super bowl star alicia key o...  ),
#  TaggedDocument(words=['blogger', 'grounded', 'airline', 'u', 'airline', 'attendant', 'fighting', 'job', 'suspended', 'posting', 'blog', 'online', 'fictional', 'account', 'life', 'eeoc', 'spokesperson', 'delta', 'airline', 'told', 'bbc', 'news', 'online', 'tell', 'discus', 'internal', 'employee', 'issue', 'blogging', 'employee', 'cross'], tags=                                                text1  \
#  22  blogger grounded airline u airline attendant f...
#
#                                                  text2
#  22  xbox power cable fire fear microsoft said repl...  ),
#  TaggedDocument(words=['xbox', 'power', 'cable', 'fire', 'fear', 'microsoft', 'said', 'replace', 'million', 'power', 'cable', 'xbox', 'console', 'due', 'safety', 'console', 'region', 'made', 'january', 'microsoft', 'said', 'received', 'report', 'minor', 'injury', 'property', 'damage', 'due', 'faulty', 'xbox', 'expected', 'released', 'end', 'year', 'beginning'], tags=                                                text1  \
#  22  blogger grounded airline u airline attendant f...
#
#                                                  text2
#  22  xbox power cable fire fear microsoft said repl...  ),
#  TaggedDocument(words=['asia', 'share', 'defy', 'post', 'quake', 'gloom', 'indonesian', 'indian', 'hong', 'kong', 'stock', 'market', 'reached', 'record', 'affected', 'area', 'developed', 'tragedy', 'would', 'little', 'impact', 'asia', 'listed', 'necessarily', 'really', 'big', 'thing', 'economic', 'affected', 'region', 'south', 'east', 'annual', 'growth', 'may', 'since', 'weekend', 'still', 'higher', 'start', 'thailand', 'may', 'lose', 'bn', 'baht', 'earnings', 'tourism', 'next', 'three', 'month', 'according', 'tourism', 'minister', 'sontaya', 'around', 'bn', 'baht', 'rebuilding', 'united', 'nation', 'recognised', 'economic', 'mainstay', 'could', 'run', 'odd', 'resort', 'severely', 'damaged', 'similar', 'number', 'suffered', 'significant'], tags=                                                text1  \
#  23  asia share defy post quake gloom indonesian in...
#
#                                                  text2
#  23  murray make cup history andrew murray become b...  ),
#  TaggedDocument(words=['murray', 'make', 'cup', 'history', 'andrew', 'murray', 'become', 'britain', 'youngest', 'ever', 'davis', 'cup', 'player', 'confirmed', 'play', 'double', 'israel', 'year', 'old', 'play', 'alongside', 'fellow', 'debutant', 'david', 'sherwood', 'israel', 'jonathan', 'erlich', 'andy', 'previously', 'played', 'two', 'single', 'rubber', 'australia', 'face', 'noam', 'double', 'pair', 'andy', 'ram', 'jonathan', 'erlich', 'among', 'top', 'eight', 'world', 'fancy', 'chance', 'in', 'british', 'tennis', 'official', 'past', 'seize', 'young', 'got', 'keep', 'pushing'], tags=                                                text1  \
#  23  asia share defy post quake gloom indonesian in...
#
#                                                  text2
#  23  murray make cup history andrew murray become b...  ),
#  TaggedDocument(words=['japanese', 'growth', 'grind', 'halt', 'growth', 'japan', 'evaporated', 'three', 'month', 'september', 'sparking', 'renewed', 'concern', 'economy', 'long', 'decade', 'long', 'annual', 'rate', 'export', 'usual', 'engine', 'recovery', 'faltered', 'domestic', 'demand', 'stayed', 'subdued', 'corporate', 'investment', 'also', 'fell', 'price', 'falling', 'rather', 'rising', 'made', 'japanese', 'shopper', 'cautious', 'kept', 'growth', 'rate', 'falling', 'dollar', 'mean', 'product', 'shipped', 'u', 'becoming', 'relatively', 'second', 'showing', 'economist', 'predicting', 'much', 'time'], tags=                                                text1  \
#  24  japanese growth grind halt growth japan evapor...
#
#                                                  text2
#  24  nortel profit revision telecom equipment maker...  ),
#  TaggedDocument(words=['nortel', 'profit', 'revision', 'telecom', 'equipment', 'maker', 'nortel', 'network', 'sharply', 'revised', 'downwards', 'profit', 'fiscal', 'awaited', 'filing', 'nortel', 'said', 'made', 'compared', 'previously', 'reported', 'revised', 'audit', 'led', 'sacking', 'canadian', 'firm', 'chief', 'showed', 'revenue', 'higher', 'first', 'value', 'since', 'last', 'year', 'climbed', 'toronto', 'period', 'previously', 'indicated', 'understated', 'none', 'involved', 'directly', 'accounting', 'revised', 'figure', 'voluntarily', 'agreed', 'repay', 'bonus', 'awarded', 'totalling'], tags=                                                text1  \
#  24  japanese growth grind halt growth japan evapor...
#
#                                                  text2
#  24  nortel profit revision telecom equipment maker...  ),
#  TaggedDocument(words=['box', 'office', 'blow', 'alexander', 'director', 'oliver', 'stone', 'historical', 'epic', 'alexander', 'failed', 'bid', 'conquer', 'box', 'office', 'entering', 'u', 'film', 'chart', 'number', 'make', 'earned', 'three', 'day', 'u', 'box', 'top', 'box', 'office', 'second', 'week', 'action', 'movie', 'national', 'ahead', 'animated', 'comedy', 'incredibles', 'fourth', 'week', 'chart', 'took', 'last', 'week', 'oliver', 'stone', 'film', 'met', 'scathing', 'review', 'u', 'relentless', 'arrogant', 'warrior', 'conquered', 'much', 'known', 'world', 'age', 'particular', 'portrayal', 'alexander', 'bisexual', 'met', 'hostile', 'reception', 'threat', 'legal', 'action', 'greek', 'sinew', 'bravado', 'expect', 'oliver', 'stone', 'three', 'hour', 'buttnumbathon', 'hamstrung', 'hectoring', 'grandiosity', 'wrote', 'one', 'reviewer', 'rolling', 'stone', 'breaking', 'frank', 'depiction'], tags=                                                text1  \
#  25  box office blow alexander director oliver ston...
#
#                                                  text2
#  25  totp turn elvis impersonator top pop turned st...  ),
#  TaggedDocument(words=['totp', 'turn', 'elvis', 'impersonator', 'top', 'pop', 'turned', 'star', 'elvis', 'presley', 'musical', 'jailhouse', 'rock', 'late', 'rock', 'legend', 'scooped', 'uk', 'th', 'number', 'one', 'topper', 'release', 'fool', 'course', 'give', 'third', 'number', 'one', 'three', 'role', 'presley', 'played', 'film'], tags=                                                text1  \
#  25  box office blow alexander director oliver ston...
#
#                                                  text2
#  25  totp turn elvis impersonator top pop turned st...  ),
#  TaggedDocument(words=['deutsche', 'telekom', 'see', 'mobile', 'gain', 'german', 'telecom', 'firm', 'deutsche', 'telekom', 'saw', 'strong', 'fourth', 'quarter', 'profit', 'back', 'upbeat', 'u', 'mobile', 'earnings', 'better', 'expected', 'asset', 'bn', 'dramatic', 'change', 'loss', 'euro', 'sale', 'rose', 'bn', 'mobile', 'usa', 'company', 'american', 'mobile', 'business', 'made', 'strong', 'contribution'], tags=                                                text1  \
#  26  deutsche telekom see mobile gain german teleco...
#
#                                                  text2
#  26  warning u pension deficit taxpayer may bail u ...  ),
#  TaggedDocument(words=['warning', 'u', 'pension', 'deficit', 'taxpayer', 'may', 'bail', 'u', 'agency', 'protects', 'worker', 'pension', 'fund', 'leading', 'economist', 'pbgc', 'bn', 'deficit', 'financial', 'economist', 'roundtable', 'fer', 'want', 'congress', 'strapped', 'u', 'company', 'including', 'airline', 'car', 'making', 'steel', 'industry', 'argued', 'favour', 'rule', 'change', 'claiming', 'funding', 'insurance', 'premium', 'adequately', 'would', 'force', 'cut', 'bn', 'hole', 'pilot', 'pension', 'scheme', 'pbgc'], tags=                                                text1  \
#  26  deutsche telekom see mobile gain german teleco...
#
#                                                  text2
#  26  warning u pension deficit taxpayer may bail u ...  ),
#  TaggedDocument(words=['evil', 'twin', 'fear', 'wireless', 'net', 'people', 'using', 'wireless', 'high', 'speed', 'net', 'wi', 'fi', 'warned', 'fake', 'hotspot', 'access', 'fi', 'becoming', 'popular', 'device', 'come', 'wireless', 'fi', 'hotspot', 'league', 'number', 'hotspot', 'expected', 'reach', 'according', 'fi', 'enabled', 'laptop', 'portable', 'device', 'order', 'conduct', 'financial', 'transaction', 'anything', 'sensitive', 'personal', 'nature', 'said', 'professor', 'brian', 'collins', 'head', 'information', 'system', 'cranfield', 'fi', 'device', 'security', 'measure', 'activated', 'fi', 'fi', 'network', 'le', 'vulnerable', 'mean', 'accessing', 'internet', 'like', 'broadband', 'dial', 'fi', 'increasing', 'popularity', 'people', 'want', 'use', 'high', 'speed', 'net', 'move', 'fear', 'secure', 'fi', 'hotspot', 'offered', 'company', 'like', 'bt', 'openzone', 'cloud', 'accessible', 'user', 'sign', 'pay', 'fi', 'network', 'left', 'unprotected', 'sniffed', 'hi', 'jacked', 'anyone', 'correct'], tags=                                                text1  \
#  27  evil twin fear wireless net people using wirel...
#
#                                                  text2
#  27  broadband uk growing fast high speed net conne...  ),
# ...
#  489  howard reject bnp claim tory leader michael ho...
#
#                                                   text2
#  489  lister flock gervais sitcom hollywood actor sa...  ),
#  TaggedDocument(words=['ajax', 'refuse', 'rule', 'jol', 'move', 'ajax', 'refused', 'reveal', 'whether', 'tottenham', 'bos', 'martin', 'jol', 'dutch', 'champion', 'shortlist', 'become', 'amsterdam', 'club', 'new', 'coach', 'understands', 'dutch', 'league', 'offensive', 'distinctive'], tags=                                                 text1  \
#  490  ajax refuse rule jol move ajax refused reveal ...
#
#                                                   text2
#  490  cheaper chip mobile mobile phone chip combine ...  ),
#  TaggedDocument(words=['cheaper', 'chip', 'mobile', 'mobile', 'phone', 'chip', 'combine', 'modem', 'computer', 'processor', 'one', 'bit', 'silicon', 'instead', 'two', 'could', 'make', 'phone', 'cheaper', 'designed', 'chip', 'developed', 'texas', 'instrument', 'could', 'drive', 'cost', 'making', 'mobile', 'capable', 'gaming', 'frame', 'second', 'vox', 'tested', 'firm', 'europe', 'asia', 'could', 'appear', 'end', 'potato', 'phone', 'largest', 'market', 'share', 'said', 'doug', 'rasor', 'marketing', 'vice', 'president', 'mobile', 'technology', 'offer', 'high', 'speed', 'network', 'video', 'streaming', 'multimedia', 'end', 'phone', 'mobile', 'owner', 'thinking', 'upgrading', 'speed', 'network', 'known', 'super', 'intended', 'time', 'faster', 'designed', 'omap', 'vox', 'chip', 'set', 'announced', 'ahead', 'start', 'major', 'mobile', 'industry', 'conference', 'gsm', 'take', 'place', 'cannes', 'france'], tags=                                                 text1  \
#  490  ajax refuse rule jol move ajax refused reveal ...
#
#                                                   text2
#  490  cheaper chip mobile mobile phone chip combine ...  ),
#  TaggedDocument(words=['call', 'save', 'manufacturing', 'job', 'trade', 'union', 'congress', 'tuc', 'calling', 'government', 'stem', 'job', 'loss', 'manufacturing', 'firm', 'reviewing', 'help', 'give', 'page', 'submission', 'also', 'urge', 'government', 'examine', 'support', 'european', 'country', 'provide'], tags=                                                 text1  \
#  491  call save manufacturing job trade union congre...
#
#                                                   text2
#  491  yukos sue four firm bn russian oil firm yukos ...  ),
#  TaggedDocument(words=['yukos', 'sue', 'four', 'firm', 'bn', 'russian', 'oil', 'firm', 'yukos', 'sued', 'four', 'company', 'role', 'last', 'year', 'forced', 'state', 'auction', 'key', 'oil', 'production', 'unit', 'bn', 'bn', 'damage', 'yugansk', 'sold', 'december', 'settle', 'back', 'bn', 'back', 'tax', 'unpaid', 'day', 'hearing', 'february', 'hear', 'argument', 'whether', 'u', 'court', 'proper', 'forum', 'known', 'investment', 'firm', 'baikal', 'finance', 'run', 'oil', 'group', 'rosneft'], tags=                                                 text1  \
#  491  call save manufacturing job trade union congre...
#
#                                                   text2
#  491  yukos sue four firm bn russian oil firm yukos ...  ),
#  TaggedDocument(words=['window', 'worm', 'travel', 'tetri', 'user', 'warned', 'window', 'virus', 'pose', 'hugely', 'popular', 'tetri', 'mail', 'like', 'many', 'rather', 'something', 'cause', 'concern', 'said', 'graham', 'cluley', 'spokesman', 'anti', 'virus', 'firm', 'virus', 'software', 'keep'], tags=                                                 text1  \
#  492  window worm travel tetri user warned window vi...
#
#                                                   text2
#  492  sundance honour foreign film international fil...  ),
#  TaggedDocument(words=['sundance', 'honour', 'foreign', 'film', 'international', 'film', 'given', 'prominence', 'u', 'film', 'next', 'year', 'sundance', 'film', 'festival', 'movie', 'dominated', 'theme', 'january', 'season', 'two', 'film', 'debut', 'sundance', 'including', 'liberace', 'baghdad', 'british', 'director', 'sean', 'israeli', 'production', 'wall', 'look', 'israel', 'controversial', 'security', 'wall', 'separating', 'palestinian', 'fi', 'thriller', 'primer', 'written', 'directed', 'shane'], tags=                                                 text1  \
#  492  window worm travel tetri user warned window vi...
#
#                                                   text2
#  492  sundance honour foreign film international fil...  ),
#  TaggedDocument(words=['asia', 'quake', 'increase', 'poverty', 'risk', 'nearly', 'two', 'million', 'people', 'across', 'asia', 'could', 'thrown', 'poverty', 'indian', 'ocean', 'tsunami', 'asian', 'development', 'bank', 'adb', 'income', 'people', 'could', 'enormous', 'paris', 'club', 'rich', 'creditor', 'nation', 'wednesday', 'offered', 'freeze', 'debt', 'owed', 'tsunami', 'hit', 'disaster', 'relief', 'next', 'six', 'month', 'according', 'united', 'risk', 'falling', 'population', 'already', 'life', 'le', 'day', 'could', 'rise'], tags=                                                 text1  \
#  493  asia quake increase poverty risk nearly two mi...
#
#                                                   text2
#  493  verizon seal takeover mci verizon takeover bat...  ),
#  TaggedDocument(words=['verizon', 'seal', 'takeover', 'mci', 'verizon', 'takeover', 'battle', 'u', 'phone', 'firm', 'mci', 'bid', 'worth', 'bn', 'bn', 'report', 'distance', 'giant', 'bought', 'former', 'subsidiary', 'sbc', 'earlier', 'year', 'bn', 'company', 'collapsed', 'worker', 'lost', 'bn', 'standard', 'behaviour', 'paying', 'security', 'exchange', 'commission', 'october', 'settle', 'charge', 'manipulated', 'result', 'keep', 'wall', 'street', 'biggest', 'long', 'distance', 'firm', 'dollar', 'telecom', 'deal', 'since', 'based', 'factor', 'may', 'swung', 'board', 'favour', 'since', 'suitor', 'offering', 'mixture', 'cash'], tags=                                                 text1  \
#  493  asia quake increase poverty risk nearly two mi...
#
#                                                   text2
#  493  verizon seal takeover mci verizon takeover bat...  ),
#  TaggedDocument(words=['british', 'library', 'get', 'wireless', 'net', 'visitor', 'british', 'library', 'able', 'get', 'wireless', 'internet', 'access', 'alongside', 'extensive', 'information', 'available', 'famous', 'reading', 'restaurant', 'outdoor', 'piazza', 'visitor', 'library', 'carried', 'access', 'mail', 'study', 'hour', 'session', 'monthly', 'visitor', 'came', 'library', 'sit', 'use', 'business', 'mail', 'well', 'british', 'library'], tags=                                                 text1  \
#  494  british library get wireless net visitor briti...
#
#                                                   text2
#  494  campaign cold call questioned labour conservat...  ),
#  TaggedDocument(words=['campaign', 'cold', 'call', 'questioned', 'labour', 'conservative', 'still', 'telephoning', 'million', 'people', 'signed', 'make', 'sure', 'get', 'marketing', 'cold', 'call', 'party', 'say', 'stick', 'rule', 'ensuring', 'call', 'marketing', 'instance', 'asking', 'people', 'voting', 'general', 'tps', 'list', 'ban', 'unsolicited', 'sale', 'marketing', 'election', 'reminded'], tags=                                                 text1  \
#  494  british library get wireless net visitor briti...
#
#                                                   text2
#  494  campaign cold call questioned labour conservat...  ),
#  TaggedDocument(words=['german', 'business', 'confidence', 'slide', 'german', 'business', 'confidence', 'fell', 'february', 'knocking', 'hope', 'speedy', 'recovery', 'europe', 'largest', 'based', 'research', 'institute', 'ifo', 'said', 'confidence', 'index', 'fell', 'february', 'january', 'first', 'decline', 'three', 'last', 'year', 'shrinking', 'however', 'economy', 'contracted', 'last', 'three', 'month', 'mainly', 'due', 'reluctance', 'consumer', 'werner', 'sinn', 'said', 'improvement', 'german', 'domestic', 'demand', 'manufacturing', 'firm', 'including', 'daimlerchrysler', 'siemens', 'volkswagen', 'negotiating', 'union', 'cost', 'cutting', 'comment', 'senior', 'official', 'recently', 'focused', 'threat', 'inflation', 'prompting', 'fear', 'interest', 'rate', 'may'], tags=                                                 text1  \
#  495  german business confidence slide german busine...
#
#                                                   text2
#  495  gm ford cut output sale fall u car firm genera...  ),
#  TaggedDocument(words=['gm', 'ford', 'cut', 'output', 'sale', 'fall', 'u', 'car', 'firm', 'general', 'motor', 'gm', 'ford', 'forced', 'cut', 'production', 'face', 'falling', 'car', 'february', 'compared', 'year', 'ago', 'ford', 'sale', 'dropped', 'foreign', 'rival', 'took', 'bigger', 'share', 'toyota', 'sale', 'jumped', 'rival', 'nissan', 'notched', 'guzzling', 'sport', 'utility', 'vehicle', 'suv', 'vehicle', 'provide', 'biggest', 'february', 'car', 'business', 'tumbled', 'however', 'acknowledge', 'new', 'product', 'pontiac', 'chevrolet', 'cobalt', 'put', 'solid', 'already', 'reduced', 'output', 'around', 'face', 'growing', 'quarter', 'north', 'american', 'production', 'another', 'vehicle', 'chrysler', 'u', 'unit', 'germany', 'daimlerchrysler', 'detroit', 'based', 'automaker', 'boast', 'increase', 'market', 'share', 'month', 'sale', 'rising', 'america', 'loss', 'foreign', 'rival', 'gain', 'continued', 'nibble', 'away', 'u', 'year', 'surge', 'february', 'surge', 'sale', 'gas', 'electric', 'prius', 'hybrid', 'mid', 'size', 'sedan', 'petrol', 'price', 'conscious', 'consumer', 'looked', 'vehicle', 'cheaper'], tags=                                                 text1  \
#  495  german business confidence slide german busine...
#
#                                                   text2
#  495  gm ford cut output sale fall u car firm genera...  ),
#  TaggedDocument(words=['u', 'bank', 'bos', 'hail', 'genius', 'smith', 'u', 'federal', 'reserve', 'chairman', 'alan', 'greenspan', 'given', 'speech', 'scottish', 'church', 'honour', 'pioneering', 'economist', 'adam', 'enhancing', 'emanation', 'interest', 'laissez', 'faire', 'economics', 'competition', 'force', 'good', 'especially', 'smith', 'toiling', 'environs', 'kirkcaldy', 'created', 'modern', 'vision', 'people', 'free', 'choose', 'act', 'according', 'individual', 'self', 'interest', 'received', 'honorary', 'knighthood', 'queen', 'balmoral', 'awarded', 'honorary', 'fellowship', 'royal', 'society', 'became', 'chairman', 'federal', 'reserve', 'unprecedented', 'fifth', 'term', 'june', 'step', 'january', 'next'], tags=                                                 text1  \
#  496  u bank bos hail genius smith u federal reserve...
#
#                                                   text2
#  496  saab build cadillacs sweden general motor worl...  ),
#  TaggedDocument(words=['saab', 'build', 'cadillacs', 'sweden', 'general', 'motor', 'world', 'largest', 'car', 'maker', 'confirmed', 'build', 'new', 'medium', 'sized', 'cadillac', 'bls', 'loss', 'making', 'saab', 'factory', 'sized', 'luxury', 'car', 'peter', 'bmw', 'mercedes', 'even', 'presidential', 'limousine', 'carry', 'needed', 'scale', 'saab', 'factory', 'currently', 'produce', 'fewer', 'car', 'per', 'albeit', 'loss', 'halved', 'euro', 'previous', 'badged', 'vauxhalls', 'uk', 'cadillacs', 'framework', 'allowing', 'different', 'brand', 'share'], tags=                                                 text1  \
#  496  u bank bos hail genius smith u federal reserve...
#
#                                                   text2
#  496  saab build cadillacs sweden general motor worl...  ),
#  TaggedDocument(words=['bank', 'voted', 'rate', 'change', 'decision', 'keep', 'interest', 'rate', 'hold', 'earlier', 'month', 'passed', 'bank', 'england', 'rate', 'setting', 'body', 'minute', 'mpc', 'paul', 'tucker', 'voted', 'raise', 'rate', 'news', 'surprised', 'analyst', 'expected', 'latest', 'minute', 'show', 'another', 'unanimous', 'argued', 'economic', 'growth', 'picking', 'equity', 'credit', 'housing', 'market', 'stronger'], tags=                                                 text1  \
#  497  bank voted rate change decision keep interest ...
#
#                                                   text2
#  497  aviator vera take bafta glory hollywood blockb...  ),
#  TaggedDocument(words=['aviator', 'vera', 'take', 'bafta', 'glory', 'hollywood', 'blockbuster', 'aviator', 'low', 'budget', 'british', 'movie', 'vera', 'drake', 'shared', 'main', 'honour', 'bafta', 'film', 'handed', 'saturday', 'despite', 'two', 'nomination', 'best', 'nominated', 'owen', 'told', 'reporter', 'whole', 'award', 'season', 'new', 'anything', 'hair', 'production', 'design', 'vera', 'drake', 'also', 'scooped', 'best', 'costume', 'pic', 'late', 'singer', 'ray', 'charles', 'also', 'took', 'best'], tags=                                                 text1  \
#  497  bank voted rate change decision keep interest ...
#
#                                                   text2
#  497  aviator vera take bafta glory hollywood blockb...  ),
#  TaggedDocument(words=['lacroix', 'label', 'bought', 'u', 'firm', 'luxury', 'good', 'group', 'lvmh', 'sold', 'loss', 'making', 'christian', 'lacroix', 'clothing', 'label', 'u', 'investment', 'based', 'firm', 'shedding', 'non', 'core', 'business', 'focusing', 'profitable', 'brand', 'including', 'moet', 'chandon', 'champagne', 'louis', 'wear', 'label', 'purchased', 'falic', 'group', 'unspecified', 'based', 'falic', 'group', 'also', 'run', 'chain', 'duty', 'free', 'store', 'u', 'said', 'planned', 'expand', 'brand', 'opening', 'new'], tags=                                                 text1  \
#  498  lacroix label bought u firm luxury good group ...
#
#                                                   text2
#  498  incredibles win animation award incredibles mo...  ),
#  TaggedDocument(words=['incredibles', 'win', 'animation', 'award', 'incredibles', 'movie', 'beaten', 'shrek', 'main', 'prize', 'hollywood', 'animation', 'award', 'shrek', 'seven', 'nomination', 'went', 'home', 'empty', 'around', 'world', 'compared'], tags=                                                 text1  \
#  498  lacroix label bought u firm luxury good group ...
#
#                                                   text2
#  498  incredibles win animation award incredibles mo...  ),
#  TaggedDocument(words=['connell', 'reject', 'lion', 'rumour', 'ireland', 'munster', 'lock', 'paul', 'connell', 'dismissed', 'medium', 'report', 'linking', 'captaincy', 'lion', 'tour', 'new', 'zealand', 'runner', 'job', 'say', 'totally', 'focused', 'sunday', 'six', 'nation', 'crunch', 'clash', 'scoring', 'international', 'debut', 'wale', 'two', 'year', 'ago', 'enjoying', 'meteoric', 'rise', 'rugby', 'shop', 'window', 'refuse', 'drawn', 'breaker', 'josh', 'lewsey', 'jason', 'robinson', 'charlie', 'hodgson', 'ready', 'click', 'ended', 'getting', 'hammered', 'know', 'happen', 'england', 'come'], tags=                                                 text1  \
#  499  connell reject lion rumour ireland munster loc...
#
#                                                   text2
#  499  wenger handed summer war chest arsenal bos ars...  ),
#  TaggedDocument(words=['wenger', 'handed', 'summer', 'war', 'chest', 'arsenal', 'bos', 'arsene', 'wenger', 'guaranteed', 'transfer', 'fund', 'boost', 'squad', 'stadium', 'affect', 'wenger', 'spending'], tags=                                                 text1  \
#  499  connell reject lion rumour ireland munster loc...
#
#                                                   text2
#  499  wenger handed summer war chest arsenal bos ars...  ),
#  ...]

# %% [markdown]
# # Model

# %% [markdown]
# Initializing model

# %%
model = Doc2Vec(dm = 1, min_count=1, window=20, vector_size=300, sample=1e-4, negative=10, workers=1, seed=42, dm_mean=1)
model.build_vocab(text_labeled)

# %% [markdown]
# Training model

# %%
for epoch in range(20):
    model.train(text_labeled,epochs=model.epochs,total_examples=model.corpus_count)
    print("Epoch #{} is complete.".format(epoch+1))
# Out:
# Epoch #1 is complete.
# Epoch #2 is complete.
# Epoch #3 is complete.
# Epoch #4 is complete.
# Epoch #5 is complete.
# Epoch #6 is complete.
# Epoch #7 is complete.
# Epoch #8 is complete.
# Epoch #9 is complete.
# Epoch #10 is complete.
# Epoch #11 is complete.
# Epoch #12 is complete.
# Epoch #13 is complete.
# Epoch #14 is complete.
# Epoch #15 is complete.
# Epoch #16 is complete.
# Epoch #17 is complete.
# Epoch #18 is complete.
# Epoch #19 is complete.
# Epoch #20 is complete.

# %%
print('No. of vocabulary words in model:', len(model.wv.vocab))
# Out:
# No. of vocabulary words in model: 14233

# %% [markdown]
# Splitting each word in a row to match vocab during model evaluation

# %%
text1_split = []
for text in text1:
    text1_split.append(text.split())
    
text2_split = []
for text in text2:
    text2_split.append(text.split())

# %% [markdown]
# # Evaluating model

# %%
doc2vec_scores = []

# %%
for i in range(len(text1_split)):
    score = model.wv.n_similarity(text1_split[i], text2_split[i])
    doc2vec_scores.append(score)

# %%
mean_score = sum(doc2vec_scores) / len(doc2vec_scores)

# %%
print('Mean score', mean_score)
# Out:
# Mean score 0.42930078250523857

# %% [markdown]
# # Saving predictions

# %%
output = pd.DataFrame({'Unique_ID': Unique_ID,
                       'Similarity_Score': doc2vec_scores})

output.to_csv(r'submission.csv', index=False)

# %%
model.wv.n_similarity(text1_split[0], text2_split[0])
# Out:
# 0.5068366
